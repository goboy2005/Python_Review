# %% [markdown]
# <a href="https://colab.research.google.com/github/goboy2005/Python_Review/blob/main/Python%20Day%203%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#54
import random
dice=range(1,7)
cnt=0
for i in range(1,11):
  result=random.choice(dice)
  if result==3:
    cnt=cnt+1
print(cnt)

# %%
#55
import random
cnt=0
dice=range(1,7)
for i in range(1,11):
  result=random.choice(dice)
  if result%2==0:
    cnt=cnt+1
print(cnt)
# Out:
# 3

# %%
#56
import random
dice1=range(1,7)
dice2=range(1,7)
cnt=0
for i in range(1,101):
  result1=random.choice(dice1)
  result2=random.choice(dice2)
  if result1+result2==10:
    cnt=cnt+1
print(cnt)
# Out:
# 12

# %%
#57
import math
print(2*math.log2(10)+(1/3)*math.log2(10))
# Out:
# 7.751165554737178

# %%
#59
import random
dice=range(1,7)
cnt=0
for i in range(1,11):
  result=random.choice(dice)
  if result==3:
    cnt+=1
print(cnt)
# Out:
# 1

# %%
#60
import random
dice=[1,2,3,4,5,6]
cnt=0
for i in range(1,21):
  result=random.choice(dice)
  if result>=4:
    cnt=cnt+1
print(cnt)
# Out:
# 11

# %%
#61

cnt=0
for i in range(1,289):
  result=random.choice(dice)
  if result>=5:
    cnt=cnt+1
print(cnt)
# Out:
# 105

# %%
#62
cnt=0
for i in range(1,289):
  result=random.choice(dice)
  if result>=5:
    cnt=cnt+1
print(cnt/288)
# Out:
# 0.3784722222222222

# %%
#63
a=[]
for j in range(1,1001):
  cnt=0
  for i in range(1,289):
    result=random.choice(dice)
    if result>=5:
      cnt=cnt+1
  a.append(cnt/288)
print(a)
# Out:
# [0.3194444444444444, 0.3506944444444444, 0.3541666666666667, 0.2951388888888889, 0.3506944444444444, 0.3888888888888889, 0.3645833333333333, 0.3194444444444444, 0.2847222222222222, 0.3506944444444444, 0.34375, 0.3125, 0.3263888888888889, 0.3055555555555556, 0.3368055555555556, 0.3368055555555556, 0.3263888888888889, 0.2986111111111111, 0.3298611111111111, 0.3645833333333333, 0.3819444444444444, 0.3541666666666667, 0.2986111111111111, 0.3298611111111111, 0.3333333333333333, 0.3680555555555556, 0.3194444444444444, 0.2986111111111111, 0.3263888888888889, 0.3368055555555556, 0.3229166666666667, 0.40625, 0.3263888888888889, 0.3541666666666667, 0.3541666666666667, 0.3263888888888889, 0.2951388888888889, 0.3472222222222222, 0.3402777777777778, 0.3819444444444444, 0.3229166666666667, 0.3090277777777778, 0.3298611111111111, 0.3159722222222222, 0.3229166666666667, 0.375, 0.3333333333333333, 0.3159722222222222, 0.3541666666666667, 0.3020833333333333, 0.3472222222222222, 0.3159722222222222, 0.33
# ...

# %%
#65
import random

coin=['head','tail']
cnt=0
for i in range(1,101):
  result=random.choice(coin)
  if result=='head':
    cnt+=1
print(cnt)
# Out:
# 48

# %%
#66
dice=range(1,7)
coin=['head','tail']
a=[]
for j in range(1,51):
  cnt=0
  for i in range(1,101):
    result_dice=random.choice(dice)
    result_coin=random.choice(coin)
    if result_dice==5 and result_coin=='head':
      cnt+=1
  a.append(cnt)
print(len(a))
# Out:
# 50

# %%
print(len(a))
# Out:
# 50

# %%
d = [1,2,3,4,5,6] # 주사위를 만든다.
a=[]
for j in range(1,101):   #  반복실행할 실행문을 100번 수행되게 한다. 
    cnt = 0   #  실행문1  
    for i in range(1,289):                 # 실행문2
        result = random.choice(d)
        if result >= 5:
            cnt = cnt + 1
    a.append(cnt)          

for   k   in   a:
    print (k)

# %%
for k in (a):
  print(k)

# %%
cnt=0
for k in (a):
  if k >= 90 and k <=106:
    cnt=cnt+1
print(cnt/100)
# Out:
# 0.64

# %%
#86

제품=['정상','정상','정상','정상','불량','불량']
cnt=0
for i in range(1,1001):
  result1=random.choice(제품)
  result2=random.choice(제품)
  result3=random.choice(제품)
  if result1=='정상' and result2=='정상' and result3=='정상':
    cnt=cnt+1
print(1-cnt/1000)
# Out:
# 0.722
